# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
def process_data(file_name):
    file = open(file_name, "r")
    epsilon_raw = file.read()
    spilt_index = epsilon_raw.index('validation')
    eps_str = epsilon_raw[6:spilt_index-2].split(', ')
    accuracy_str = epsilon_raw[spilt_index+17:len(epsilon_raw)-2].split(', ')
    eps = []
    accuracy = []
    for item in eps_str:
        eps.append(float(item))
    for acc in accuracy_str:
        accuracy.append(float(acc))
    return eps,accuracy

# %%
eps_1_slr,accuracy_1_slr = process_data("results/mnist_dpsgd_delta_0.01_lr_3e-06.txt")
eps_2_slr,accuracy_2_slr = process_data("results/mnist_dpsgd_delta_0.001_lr_3e-06.txt")
eps_3_slr,accuracy_3_slr = process_data("results/mnist_dpsgd_delta_0.0001_lr_3e-06.txt")
eps_4_slr,accuracy_4_slr = process_data("results/mnist_dpsgd_delta_1e-05_lr_3e-06.txt")
plt.plot(range(100), eps_1_slr, label='delta=1e-02')
plt.plot(range(100), eps_2_slr, label='delta=1e-03')
plt.plot(range(100), eps_3_slr, label='delta=1e-04')
plt.plot(range(100), eps_4_slr, label='delta=1e-05')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Epsilon')
plt.title('epoch - ε relations')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(8, 6)
plt.savefig('figures/Mnist_epoch-ε_lr_3e-06')

# %%
eps_1,accuracy_1 = process_data("results/mnist_dpsgd_delta_0.01_lr_0.001.txt")
eps_2,accuracy_2 = process_data("results/mnist_dpsgd_delta_0.001_lr_0.001.txt")
eps_3,accuracy_3 = process_data("results/mnist_dpsgd_delta_0.0001_lr_0.001.txt")
eps_4,accuracy_4 = process_data("results/mnist_dpsgd_delta_1e-05_lr_0.001.txt")
plt.plot(range(400), accuracy_1, label='delta=1e-02')
plt.plot(range(400), accuracy_2, label='delta=1e-03')
plt.plot(range(400), accuracy_3, label='delta=1e-04')
plt.plot(range(400), accuracy_4, label='delta=1e-05')
plt.savefig('Mnist_epoch-ε_lr_3e-06')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy of various (epoch, δ) privacy values')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(8, 6)
plt.savefig('figures/Mnist_accuracy-epoch_lr_e-03')

# %%
eps_1_slr,accuracy_1_slr = process_data("results/mnist_dpsgd_delta_0.01_lr_3e-06.txt")
eps_2_slr,accuracy_2_slr = process_data("results/mnist_dpsgd_delta_0.001_lr_3e-06.txt")
eps_3_slr,accuracy_3_slr = process_data("results/mnist_dpsgd_delta_0.0001_lr_3e-06.txt")
eps_4_slr,accuracy_4_slr = process_data("results/mnist_dpsgd_delta_1e-05_lr_3e-06.txt")
plt.plot(range(100), accuracy_1_slr, label='delta=1e-02')
plt.plot(range(100), accuracy_2_slr, label='delta=1e-03')
plt.plot(range(100), accuracy_3_slr, label='delta=1e-04')
plt.plot(range(100), accuracy_4_slr, label='delta=1e-05')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy of various (epoch, δ) privacy values')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(8, 6)
plt.savefig('figures/Mnist_accuracy-epoch_lr_3e-06')

# %%
eps_1_slr,accuracy_1_slr = process_data("results/mnist_dpsgd_delta_0.01_lr_3e-06.txt")
eps_2_slr,accuracy_2_slr = process_data("results/mnist_dpsgd_delta_0.001_lr_3e-06.txt")
eps_3_slr,accuracy_3_slr = process_data("results/mnist_dpsgd_delta_0.0001_lr_3e-06.txt")
eps_4_slr,accuracy_4_slr = process_data("results/mnist_dpsgd_delta_1e-05_lr_3e-06.txt")
plt.plot(eps_1_slr, accuracy_1_slr, label='delta=1e-02')
plt.plot(eps_2_slr, accuracy_2_slr, label='delta=1e-03')
plt.plot(eps_3_slr, accuracy_3_slr, label='delta=1e-04')
plt.plot(eps_4_slr, accuracy_4_slr, label='delta=1e-05')
plt.legend()
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy of various (ε, δ) privacy values')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(8, 6)
plt.savefig('figures/Mnist_accuracy-epoch_lr_3e-06')

# %%
eps_1_slr,accuracy_1_slr = process_data("results/cifar_dpsgd_delta_0.0001_lr_0.001.txt")
eps_2_slr,accuracy_2_slr = process_data("results/cifar_dpsgd_delta_1e-05_lr_0.001.txt")
eps_3_slr,accuracy_3_slr = process_data("results/cifar_dpsgd_delta_1e-06_lr_0.001.txt")
plt.plot(eps_1_slr, accuracy_1_slr, label='delta=1e-04')
plt.plot(eps_2_slr, accuracy_2_slr, label='delta=1e-05')
plt.plot(eps_3_slr, accuracy_3_slr, label='delta=1e-05')
plt.legend()
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy of various (ε, δ) privacy values')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(8, 6)

# %%
eps_1_slr,accuracy_1_slr = process_data("results/cifar_dpsgd_delta_0.0001_lr_0.001.txt")
eps_2_slr,accuracy_2_slr = process_data("results/cifar_dpsgd_delta_1e-05_lr_0.001.txt")
eps_3_slr,accuracy_3_slr = process_data("results/cifar_dpsgd_delta_1e-06_lr_0.001.txt")
plt.plot(range(200), accuracy_1_slr, label='delta=1e-04')
plt.plot(range(200), accuracy_2_slr, label='delta=1e-05')
plt.plot(range(200), accuracy_3_slr, label='delta=1e-05')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy of various (epoch, δ) privacy values')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(8, 6)
